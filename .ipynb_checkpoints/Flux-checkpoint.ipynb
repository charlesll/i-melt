# %%
import Flux
using Flux.Tracker, Statistics, DelimitedFiles
using Flux.Tracker: Params, gradient, update!
using Flux: gpu, Dense, relu, Chain, ADAM, RMSProp, Descent, params, throttle, Dropout, @epochs, testmode!

using Base.Iterators: repeated

using DataFrames, DataFramesMeta, ExcelFiles, MLDataUtils, HDF5, ProgressMeter, Plots, LinearAlgebra, NNlib
pyplot() # pyplot backend

using BSON: @save, @load

#using BenchmarkTools
# Out:
# ┌ Info: Precompiling Flux [587475ba-b771-5e3f-ad9e-33799f191a9c]
# └ @ Base loading.jl:1186
# ┌ Warning: Module Compat with build ID 1710547783679 is missing from the cache.
# │ This may mean Compat [34da2185-b29b-5c13-b0c7-acf172513d20] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Warning: Module Compat with build ID 1710547783679 is missing from the cache.
# │ This may mean Compat [34da2185-b29b-5c13-b0c7-acf172513d20] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Info: Precompiling MacroTools [1914dd2f-81c6-5fcd-8719-6d5c9610ff09]
# └ @ Base loading.jl:1186
# ┌ Warning: Module Compat with build ID 1710547783679 is missing from the cache.
# │ This may mean Compat [34da2185-b29b-5c13-b0c7-acf172513d20] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:947
# ┌ Info: Precompiling CSTParser [00ebfdb7-1f24-5e51-bd34-a7502290713f]
# └ @ Base loading.jl:1186

# %%
import Pkg; Pkg.add("Flux")
# Out:
#   Updating registry at `/opt/julia/registries/General`
#   Updating git-repo `https://github.com/JuliaRegistries/General.git`
# Fetching: [========================================>]  100.0 %.0 %Fetching: [=========>                               ]  20.2 %Fetching: [=========>                               ]  20.3 %Fetching: [==========>                              ]  23.4 %Fetching: [==========>                              ]  23.8 %Fetching: [============>                            ]  27.5 %Fetching: [=============>                           ]  31.7 %Fetching: [==============>                          ]  34.8 %Fetching: [===============>                         ]  35.6 %Fetching: [================>                        ]  38.6 %Fetching: [=========================>               ]  61.1 %Fetching: [==========================>              ]  63.5 %Fetching: [===========================>             ]  66.0 %Fetching: [===========================>             ]  67.1 %Fetching: [=============================>           ]  70.9 %Fetching: [=============================>           ]  72.3 %Fetching: [==============================>          ]  73.7 %77.3 %Fetching: [================================>        ]  79.8 % Resolving package versions...
#  Installed AbstractTrees ─────── v0.2.1
#  Installed ZipFile ───────────── v0.8.1
#  Installed Parsers ───────────── v0.2.22
#  Installed DocStringExtensions ─ v0.7.0
#  Installed TranscodingStreams ── v0.9.4
#  Installed Juno ──────────────── v0.7.0
#  Installed FileIO ────────────── v1.0.6
#  Installed Flux ──────────────── v0.8.2
#  Installed Compat ────────────── v2.1.0
#  Installed Ratios ────────────── v0.3.1
#  Installed Adapt ─────────────── v0.4.2
#  Installed MacroTools ────────── v0.5.0
#  Installed Tracker ───────────── v0.1.0
#  Installed OrderedCollections ── v1.1.0
#  Installed StaticArrays ──────── v0.10.3
#  Installed Optim ─────────────── v0.18.1
#  Installed NNlib ─────────────── v0.5.0
#  Installed StatsBase ─────────── v0.29.0
#  Installed EzXML ─────────────── v0.9.1
#  Installed SoftGlobalScope ───── v1.0.10
#  Installed Tokenize ──────────── v0.5.3
#  Installed LibCURL ───────────── v0.5.0
#  Installed TimeZones ─────────── v0.9.0
#  Installed CodecZlib ─────────── v0.5.2
#  Installed Distributions ─────── v0.18.0
#  Installed Tables ────────────── v0.1.18
#  Installed DiffEqDiffTools ───── v0.8.1
#  Installed AbstractFFTs ──────── v0.4.0
#  Installed CSTParser ─────────── v0.5.2
#  Installed WeakRefStrings ────── v0.5.8
#  Installed Compose ───────────── v0.7.3
#  Installed MbedTLS ───────────── v0.6.8
#   Updating `/opt/julia/environments/v1.1/Project.toml`
#   [587475ba] + Flux v0.8.2
#   Updating `/opt/julia/environments/v1.1/Manifest.toml`
#   [621f4979] ↑ AbstractFFTs v0.3.2 ⇒ v0.4.0
#   [1520ce14] + AbstractTrees v0.2.1
#   [79e6a3ab] + Adapt v0.4.2
#   [00ebfdb7] + CSTParser v0.5.2
#   [944b1d66] ↑ CodecZlib v0.5.1 ⇒ v0.5.2
#   [34da2185] ↑ Compat v1.5.1 ⇒ v2.1.0
#   [a81c6b42] ↑ Compose v0.7.2 ⇒ v0.7.3
#   [01453d9d] ↑ DiffEqDiffTools v0.8.0 ⇒ v0.8.1
#   [31c24e10] ↑ Distributions v0.16.4 ⇒ v0.18.0
#   [ffbed154] ↑ DocStringExtensions v0.6.0 ⇒ v0.7.0
#   [8f5d6c58] ↑ EzXML v0.9.0 ⇒ v0.9.1
#   [5789e2e9] ↑ FileIO v1.0.5 ⇒ v1.0.6
#   [587475ba] + Flux v0.8.2
#   [e5e0dc1b] ↑ Juno v0.5.4 ⇒ v0.7.0
#   [b27032c2] ↑ LibCURL v0.4.1 ⇒ v0.5.0
#   [1914dd2f] ↑ MacroTools v0.4.5 ⇒ v0.5.0
#   [739be429] ↑ MbedTLS v0.6.7 ⇒ v0.6.8
#   [872c559c] + NNlib v0.5.0
#   [4d1e1d77] - Nullables v0.0.8
#   [429524aa] ↑ Optim v0.17.2 ⇒ v0.18.1
#   [bac558e1] ↑ OrderedCollections v1.0.2 ⇒ v1.1.0
#   [69de0a69] ↑ Parsers v0.2.18 ⇒ v0.2.22
#   [c84ed2f1] ↑ Ratios v0.3.0 ⇒ v0.3.1
#   [b85f4697] ↑ SoftGlobalScope v1.0.9 ⇒ v1.0.10
#   [90137ffa] ↑ StaticArrays v0.10.2 ⇒ v0.10.3
#   [2913bbd2] ↑ StatsBase v0.27.0 ⇒ v0.29.0
#   [bd369af6] ↑ Tables v0.1.15 ⇒ v0.1.18
#   [f269a46b] ↑ TimeZones v0.8.5 ⇒ v0.9.0
#   [0796e94c] + Tokenize v0.5.3
#   [9f7883ad] + Tracker v0.1.0
#   [3bb67fe8] ↑ TranscodingStreams v0.8.1 ⇒ v0.9.4
#   [ea10d353] ↑ WeakRefStrings v0.5.7 ⇒ v0.5.8
#   [a5390f91] + ZipFile v0.8.1
#   Building ZipFile ──→ `/opt/julia/packages/ZipFile/YHTbb/deps/build.log`
#   Building EzXML ────→ `/opt/julia/packages/EzXML/r19gO/deps/build.log`
#   Building LibCURL ──→ `/opt/julia/packages/LibCURL/khRkY/deps/build.log`
#   Building TimeZones → `/opt/julia/packages/TimeZones/oXITd/deps/build.log`
#   Building CodecZlib → `/opt/julia/packages/CodecZlib/9jDi1/deps/build.log`
#   Building MbedTLS ──→ `/opt/julia/packages/MbedTLS/X4xar/deps/build.log`

# %% [markdown]
# # DATA IMPORT

# %%
X_columns = h5read("./data/DataSet.hdf5", "X_columns")

X_entropy_train = h5read("./data/DataSet.hdf5", "X_entropy_train")
X_entropy_train_sc = h5read("./data/DataSet.hdf5", "X_entropy_train_sc")

X_entropy_valid = h5read("./data/DataSet.hdf5", "X_entropy_valid")
X_entropy_valid_sc = h5read("./data/DataSet.hdf5", "X_entropy_valid_sc")

X_entropy_test = h5read("./data/DataSet.hdf5", "X_entropy_test")
X_entropy_test_sc = h5read("./data/DataSet.hdf5", "X_entropy_test_sc")

X_entropy_tv = [X_entropy_train X_entropy_valid]
X_entropy_sc_tv = [X_entropy_train_sc X_entropy_valid_sc]

X_tv = h5read("./data/DataSet.hdf5", "X_tv")
X_tv_sc = h5read("./data/DataSet.hdf5", "X_tv_sc")
y_tv = h5read("./data/DataSet.hdf5", "y_tv")

X_train = h5read("./data/DataSet.hdf5", "X_train")
X_train_sc = h5read("./data/DataSet.hdf5", "X_train_sc")
y_train = h5read("./data/DataSet.hdf5", "y_train")

X_valid = h5read("./data/DataSet.hdf5", "X_valid")
X_valid_sc = h5read("./data/DataSet.hdf5", "X_valid_sc")
y_valid = h5read("./data/DataSet.hdf5", "y_valid")

X_test = h5read("./data/DataSet.hdf5", "X_test")
X_test_sc = h5read("./data/DataSet.hdf5", "X_test_sc")
y_test = h5read("./data/DataSet.hdf5", "y_test")

X_scaler_mean = h5read("./data/DataSet.hdf5", "X_scaler_mean")
X_scaler_var = h5read("./data/DataSet.hdf5", "X_scaler_var")

X_raman_train = Float32.(h5read("./data/NKAS_DataSet.hdf5","X_raman_train"))
y_raman_train = Float32.(h5read("./data/NKAS_DataSet.hdf5","y_raman_train"))
X_raman_valid = Float32.(h5read("./data/NKAS_DataSet.hdf5","X_raman_test"))
y_raman_valid = Float32.(h5read("./data/NKAS_DataSet.hdf5","y_raman_test"))
X_raman_sc = Float32.((X_raman./100 .- X_scaler_mean[1:4])./sqrt.(X_scaler_var[1:4]))# rescaled X_raman

println("loaded")
println("\nFeatures in X_ arrays are")
println(X_columns)
println("\nShape of X train and valid is")
println(size(X_tv))
# Out:
# loaded
#
# Features in X_ arrays are
# ["sio2", "al2o3", "na2o", "k2o", "nbot", "ifsm", "ifst", "ap", "b", "T", "Sc", "tg", "ScT"]
#
# Shape of X train and valid is
# (13, 1145)

# %%
function prepare_datas(X_,y_)
    
    y = reshape(y_[:],1,length(y_))
    
    x = X_[1:4,:]
    ap = reshape(X_[8,:],1,size(X_,2))
    b = reshape(X_[9,:],1,size(X_,2))
    T = reshape(X_[10,:],1,size(X_,2))
    #be = reshape(X_[11,:],1,size(X_,2))
    sc = reshape(X_[11,:],1,size(X_,2))
    tg = reshape(X_[12,:],1,size(X_,2))
    return Float32.(x), Float32.(y), Float32.(T), Float32.(ap), Float32.(b), Float32.(sc), Float32.(tg)
end

function gkfolds(X_, y_, idx_label; k = 5)

    dd = kfolds(shuffleobs(unique(X_[idx_label,:])), k = k);
    
    out = []
    
    for j = 1:k
        train_lab, vald_lab = dd[j]
        train_idx = Int64[]
        valid_idx = Int64[]

        for i = 1:size(X_,2)
            if findall(X_[idx_label,i] .== train_lab) != []
                push!(train_idx, i)
            else
                push!(valid_idx, i)
            end
        end
        
        push!(out,((X_[:,train_idx],y_[train_idx]),(X_[:,valid_idx],y_[valid_idx])))
        
    end
    
    return out
end
# Out:
# gkfolds (generic function with 1 method)

# %%
nb_folds = 5
folds = gkfolds(X_train,y_train,8,k=nb_folds);

folds_entropy = gkfolds(X_entropy_tv,X_entropy_tv[11,:],12,k=nb_folds);

# %% [markdown]
# # Model

# %%
# The model

#
# With two subnetworks for Be and Sc
#

function thousands(size)
    return ones(size).*log.(10000)
    end

function tens(size)
    return ones(size).*log(10)
end

function init_both(dims)
    return ones(dims).*[log.(1000.);log.(10.)]
end

nb_neurons = 50
p_drop = 0.2

nb_channels_raman = size(y_raman,2)

c1 = Dense(4, nb_neurons, relu)
c2 = Dense(nb_neurons, nb_neurons, relu)
c3 = Dense(nb_neurons, nb_neurons, relu)
c4 = Dense(nb_neurons, nb_neurons, relu)
c5 = Dense(nb_neurons, nb_neurons, relu)
cout = Dense(nb_neurons, 2,initb=init_both)

m1 = Chain(
    c1, Dropout(p_drop),
    c2, Dropout(p_drop),
    c3, Dropout(p_drop),
    c4, Dropout(p_drop),
    #c5, Dropout(0.2),
    cout) # |> gpu

mr = Chain(
        c1,Dropout(p_drop),
        c2,Dropout(p_drop),
        Dense(nb_neurons,nb_channels_raman))
 
tg(x) = reshape(exp.(m1(x[1:4,:])[1,:]),1,size(x,2))
ScTg(x) = reshape(exp.(m1(x[1:4,:])[2,:]),1,size(x,2))

# Other stuffs

Ae = param([-2.11])

Be(x) = (12.0.-Ae).*(tg(x) .* ScTg(x))

dCp(x,T, ap, b) = ap.*(log.(T).-log.(tg(x))) .+ b.*(T.-tg(x))

model(x,T, ap, b) = Ae .+ Be(x) ./ (T.* (ScTg(x) .+ dCp(x,T, ap, b)))

mse(yp, y) = sqrt(sum((yp .- y).^2)./size(y, 2))

# loss functions

loss_n(x, T, ap, b, y_target) = mse(model(x, T, ap, b), y_target)

loss_sc(x,sc) = mse(ScTg(x),sc) # Add this to your loss

loss_tg(x,target) = mse(tg(x),target) # Add this to your loss
# Out:
# loss_tg (generic function with 1 method)

# %%
testmode!(m1)

scatter(([X_entropy_tv[12,:],X_entropy_tv[11,:]],
        [tg(X_entropy_tv).data[:],ScTg(X_entropy_tv).data[:]]),layout=2, 
    title=["Tg" "ScTg"])

# %%
plot(mr(X_raman).data[:,:])

# %% [markdown]
# # Pre-train on Raman

# %%
loss_raman(x,raman_target) = mse(mr(x),raman_target) + L2_norm*sum(norm, params(mr))

L2_norm = 0.001
loss_raman(X_raman_train,y_raman_train)
# Out:
# 79.15738718815444 (tracked)

# %%
# SC training
record_loss_raman_train = Float64[]
record_loss_raman_valid = Float64[]

testmode!(mr,false)

epoch_idx = 1; nb_epoch = 1000

dataset_raman = [(X_raman_train,y_raman_train)]

p = ProgressMeter.Progress(nb_epoch, 1)   # minimum update interval: 1 second
while epoch_idx < nb_epoch

    evalcb = () -> (push!(record_loss_raman_train, loss_raman(X_raman_train, y_raman_train).data),
                    push!(record_loss_raman_valid, loss_raman(X_raman_valid, y_raman_valid).data))
    Flux.train!(loss_raman, params(mr), dataset_raman, ADAM(0.001), cb = throttle(evalcb, 1))

    ProgressMeter.update!(p, epoch_idx)
    epoch_idx += 1
end
# Out:
# Progress: 100%|█████████████████████████████████████████|  ETA: 0:00:00

# %%
plot(record_loss_raman_train)
plot!(record_loss_raman_valid)

# %%
testmode!(mr)
plot(mr(X_raman_train).data[:,:],y_raman_train)

# %% [markdown]
# # Pre-train on only entropy + Tg

# %%
# SC training

# loss function
loss_tg_sc(x,tg_target,sc_target) = loss_tg(x,tg_target) .+ loss_sc(x,sc_target).*100.0 + L2_norm*sum(norm, params(mr))# Add this to your loss

L2_norm = 0.0001

# record loss
record_loss_sc_train = Float64[]
record_loss_sc_valid = Float64[]
record_loss_sc_tv = Float64[]

record_folds_train = Float64[]
record_folds_valid = Float64[]

# unfreeze dropout
testmode!(m1,false)

# loop details
epoch_idx = 1; optimal_epochs_s = 0; 
early_stop = 1; patience = 50
min_loss_val = 30000000.0

# loop
p = ProgressMeter.Progress(patience, 1)   # minimum update interval: 1 second
while early_stop < patience

    for j =1:nb_folds

        train,valid = folds_entropy[j]
        x_train_, y_train_, T_train_, ap_train_, b_train_, sc_train_, tg_train_ = prepare_datas(train[1],train[2])
        x_valid_, y_valid_, T_valid_, ap_valid_, b_valid_, sc_valid_, tg_valid_ = prepare_datas(valid[1],valid[2])

        evalcb = () -> (push!(record_folds_train, loss_tg_sc(x_train_, tg_train_, sc_train_).data),
            push!(record_folds_valid, loss_tg_sc(x_valid_, tg_valid_, sc_valid_).data))
        Flux.train!(loss_tg_sc, params(c3,cout), [(x_train_, tg_train_, sc_train_)], ADAM(0.001), cb = throttle(evalcb, 1))

    end

    push!(record_loss_sc_train, 1.0./convert(Float64,nb_folds).*sum(record_folds_train))
    push!(record_loss_sc_valid, 1.0./convert(Float64,nb_folds).*sum(record_folds_valid))

    record_folds_train = Float64[]
    record_folds_valid = Float64[]

    ProgressMeter.update!(p, early_stop)

    # Early stopping criterion
    if record_loss_sc_valid[epoch_idx] < min_loss_val
        early_stop = 0
        optimal_epochs = epoch_idx
        min_loss_val = record_loss_sc_valid[epoch_idx]
    else
        early_stop += 1
    end
    epoch_idx += 1
end
# Out:
# Progress:  96%|███████████████████████████████████████▍ |  ETA: 0:00:00

# %%
testmode!(m1)
scatter([X_entropy_train[12,:],X_entropy_train[11,:]],
    [tg(X_entropy_train).data[:],ScTg(X_entropy_train).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

scatter!([X_entropy_valid[12,:],X_entropy_valid[11,:]],
    [tg(X_entropy_valid).data[:],ScTg(X_entropy_valid).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

scatter!([X_entropy_test[12,:],X_entropy_test[11,:]],
    [tg(X_entropy_test).data[:],ScTg(X_entropy_test).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

plot!([[700;1500] [4;15]],[[700;1500] [4;15]])

# %%
testmode!(m1)
# Plot
plot([record_loss_sc_train],label="train",xlabel="iterations")
plot!(record_loss_sc_valid,label="valid")

# %%
plot(mr(X_raman_train).data[:,:])

# %% [markdown]
# # Train on loss global : entropy + viscosity

# %%
x_train_, y_train_, T_train_, ap_train_, b_train_, sc_train_, tg_train_ = prepare_datas(X_train,y_train)
x_valid_, y_valid_, T_valid_, ap_valid_, b_valid_, sc_valid_, tg_valid_ = prepare_datas(X_valid,y_valid)

x_entro_train_, y_entro_train_, T_entro_train_, ap_entro_train_, b_entro_train_, sc_entro_train_, tg_entro_train_ = prepare_datas(X_entropy_train,X_entropy_train[11,:])
x_entro_valid_, y_entro_valid_, T_entro_valid_, ap_entro_valid_, b_entro_valid_, sc_entro_valid_, tg_entro_valid_ = prepare_datas(X_entropy_valid,X_entropy_valid[11,:])

print("\nloss Raman: $(0.01.*loss_raman(X_raman_sc, transpose(y_raman)))")
print("\nloss tg: $(0.01.*loss_tg(x_entro_train_, tg_entro_train_))")
print("\nloss sc: $(loss_sc(x_entro_train_, sc_entro_train_))")
print("\nloss n train: $(loss_n(x_train_, T_train_ ,ap_train_, b_train_, y_train_))")

L2_norm = 0.001
loss_global(x, T, ap, b, y_target, x2, tg2_target, sc2_target, x_raman, y_raman) = 
    loss_n(x, T, ap, b, y_target) .+ 
    0.01.*loss_tg(x2,tg2_target) .+ 
    loss_sc(x2,sc2_target) .+
    0.01.*loss_raman(x_raman, y_raman) .+
    L2_norm*sum(norm, params(m1))
# Out:
# loss Raman: 0.0769736462149225 (tracked)
# loss tg: 0.7484254779296273 (tracked)
# loss sc: 1.2184609245714817 (tracked)
# loss n train: 1.4687555476191505 (tracked)
# loss_global (generic function with 1 method)

# %%
record_loss_train = Float64[]
record_loss_valid = Float64[]
    
testmode!(m1,false)

epoch_idx = 1; optimal_epochs_s = 0; 
early_stop = 1; patience = 500
min_loss_val = 30000000.0

p = ProgressMeter.Progress(5000, 1)   # minimum update interval: 1 second

dataset = [(x_train_, T_train_ ,ap_train_, b_train_, y_train_,
                x_entro_train_, tg_entro_train_, sc_entro_train_,X_raman, transpose(y_raman))]

while early_stop < patience
    
    evalcb = () -> (push!(record_loss_train, loss_global(x_train_, T_train_ ,ap_train_, b_train_, y_train_,
                x_entro_train_, tg_entro_train_, sc_entro_train_,X_raman, transpose(y_raman)).data),
                push!(record_loss_valid, loss_global(x_valid_, T_valid_ ,ap_valid_, b_valid_, y_valid_,
                x_entro_valid_, tg_entro_valid_, sc_entro_valid_,X_raman, transpose(y_raman)).data))
    Flux.train!(loss_global, params(Ae,m1,mr), dataset, ADAM(0.001), cb = throttle(evalcb, 1))

    ProgressMeter.update!(p, epoch_idx)

    # Early stopping criterion
    if record_loss_valid[epoch_idx] < min_loss_val
        early_stop = 0
        optimal_epochs = epoch_idx
        min_loss_val = record_loss_valid[epoch_idx]
        @save "./model/m1.bson" m1
        @save "./model/Ae.bson" Ae
    else
        early_stop += 1
    end
    epoch_idx += 1
    
end
# Out:
# Progress:   6%|██▋                                      |  ETA: 0:10:02
# InterruptException:
#
# Stacktrace:
#  [1] _forward at /home/charles/.julia/packages/Tracker/6wcYJ/src/lib/array.jl:375 [inlined]
#  [2] #track#1 at /home/charles/.julia/packages/Tracker/6wcYJ/src/Tracker.jl:51 [inlined]
#  [3] track at /home/charles/.julia/packages/Tracker/6wcYJ/src/Tracker.jl:51 [inlined]
#  [4] * at /home/charles/.julia/packages/Tracker/6wcYJ/src/lib/array.jl:365 [inlined]
#  [5] Dense at /home/charles/.julia/packages/Flux/lz7S9/src/layers/basic.jl:99 [inlined]
#  [6] Dense at /home/charles/.julia/packages/Flux/lz7S9/src/layers/basic.jl:110 [inlined]
#  [7] applychain(::Tuple{Dense{typeof(relu),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dropout{Float64},Dense{typeof(identity),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float64,1}}}}, ::TrackedArray{…,Array{Float32,2}}) at /home/charles/.julia/packages/Flux/lz7S9/src/layers/basic.jl:31 (repeats 5 times)
#  [8] (::Chain{Tuple{Dense{typeof(relu),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dropout{Float64},Dense{typeof(relu),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dropout{Float64},Dense{typeof(relu),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float32,1}}},Dropout{Float64},Dense{typeof(identity),TrackedArray{…,Array{Float32,2}},TrackedArray{…,Array{Float64,1}}}}})(::Array{Float32,2}) at /home/charles/.julia/packages/Flux/lz7S9/src/layers/basic.jl:33
#  [9] ScTg(::Array{Float32,2}) at ./In[306]:53
#  [10] loss_sc(::Array{Float32,2}, ::Array{Float32,2}) at ./In[306]:71
#  [11] loss_global(::Array{Float32,2}, ::Array{Float32,2}, ::Array{Float32,2}, ::Array{Float32,2}, ::Array{Float32,2}, ::Array{Float32,2}, ::Array{Float32,2}, ::Array{Float32,2}, ::Array{Float32,2}, ::Transpose{Float32,Array{Float32,2}}) at ./In[325]:13
#  [12] #15 at /home/charles/.julia/packages/Flux/lz7S9/src/optimise/train.jl:72 [inlined]
#  [13] gradient_(::getfield(Flux.Optimise, Symbol("##15#21")){typeof(loss_global),Tuple{Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Transpose{Float32,Array{Float32,2}}}}, ::Params) at /home/charles/.julia/packages/Tracker/6wcYJ/src/back.jl:97
#  [14] #gradient#24(::Bool, ::Function, ::Function, ::Params) at /home/charles/.julia/packages/Tracker/6wcYJ/src/back.jl:164
#  [15] gradient at /home/charles/.julia/packages/Tracker/6wcYJ/src/back.jl:164 [inlined]
#  [16] macro expansion at /home/charles/.julia/packages/Flux/lz7S9/src/optimise/train.jl:71 [inlined]
#  [17] macro expansion at /home/charles/.julia/packages/Juno/TfNYn/src/progress.jl:133 [inlined]
#  [18] #train!#12(::getfield(Flux, Symbol("#throttled#18")){getfield(Flux, Symbol("##throttled#10#14")){Bool,Bool,getfield(Main, Symbol("##138#139")),Int64}}, ::Function, ::Function, ::Params, ::Array{Tuple{Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Transpose{Float32,Array{Float32,2}}},1}, ::ADAM) at /home/charles/.julia/packages/Flux/lz7S9/src/optimise/train.jl:69
#  [19] (::getfield(Flux.Optimise, Symbol("#kw##train!")))(::NamedTuple{(:cb,),Tuple{getfield(Flux, Symbol("#throttled#18")){getfield(Flux, Symbol("##throttled#10#14")){Bool,Bool,getfield(Main, Symbol("##138#139")),Int64}}}}, ::typeof(Flux.Optimise.train!), ::Function, ::Params, ::Array{Tuple{Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Transpose{Float32,Array{Float32,2}}},1}, ::ADAM) at ./none:0
#  [20] top-level scope at In[336]:21

# %%
testmode!(m1)
#println("Optimal number of epochs:", optimal_epochs)
#println("Min loss val:", min_loss_val)
# Plot
plot([record_loss_train],layout=1,label="train")
plot!(record_loss_valid,label="valid")

# %%
testmode!(m1)
scatter([X_entropy_train[12,:],X_entropy_train[11,:]],
    [tg(X_entropy_train).data[:],ScTg(X_entropy_train).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

scatter!([X_entropy_valid[12,:],X_entropy_valid[11,:]],
    [tg(X_entropy_valid).data[:],ScTg(X_entropy_valid).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

scatter!([X_entropy_test[12,:],X_entropy_test[11,:]],
    [tg(X_entropy_test).data[:],ScTg(X_entropy_test).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

plot!([[700;1500] [4;15]],[[700;1500] [4;15]])

# %%
plot(mr(X_raman_sc).data[:,:],y_raman')

# %%
scatter(y_train_[:],
    model(x_train_,T_train_,ap_train_, b_train_).data[:],)
scatter!(y_valid_[:],
    model(x_valid_,T_valid_,ap_valid_, b_valid_).data[:],)
plot!([0.,16.],[0.,16.],ylim=(0,16))

print("\nloss n train: $(loss_n(x_train_, T_train_ ,ap_train_, b_train_, y_train_))")
print("\nloss n valid: $(loss_n(x_valid_, T_valid_ ,ap_valid_, b_valid_, y_valid_))")
# Out:
# loss n train: 0.8682896894333489 (tracked)
# loss n valid: 1.171977127953765 (tracked)

# %%
@save "./model/m1.bson" m1
@save "./model/Ae.bson" Ae

# %% [markdown]
# # Visualizing

# %%
na2o = collect(0.:0.01:0.25)
k2o = 0.25.-na2o
sio2 = ones(size(na2o,1)).*0.75
al2o3 = zeros(size(na2o,1))
dummy = zeros(size(na2o,1))
T = ones(size(na2o,1)).*1000.0

X_visu_NKS = [sio2 al2o3 na2o k2o dummy dummy dummy dummy dummy T dummy dummy]'

X_visu_NKS_sc = copy(X_visu_NKS)

for i = 1:7
    X_visu_NKS_sc[i,:] = (X_visu_NKS_sc[i,:].- X_scaler_mean[i])./sqrt.(X_scaler_var[i]) 
end


scatter(X_visu_NKS[4,:]./(X_visu_NKS[3,:].+X_visu_NKS[4,:]),ScTg(X_visu_NKS_sc).data'[:])
scatter!([0,0.28,0.53,0.82,1.0],[32.91,40.31,37.81,35.59,32.99]./7.0.*2.0,label="richet 1984")

# %%
sio2 = collect(0.6:0.01:1.)
al2o3 = zeros(size(sio2,1))
na2o = 1.0.-sio2
k2o = zeros(size(sio2,1))
dummy = zeros(size(sio2,1))
T = ones(size(sio2,1)).*1000.0
X_visu_NS = [sio2 al2o3 na2o k2o dummy dummy dummy dummy dummy T dummy dummy]'

X_visu_NS_sc = copy(X_visu_NS)

for i = 1:7
    X_visu_NS_sc[i,:] = (X_visu_NS_sc[i,:].- X_scaler_mean[i])./sqrt.(X_scaler_var[i]) 
end
#x_visu_xaxis = X_visu_NKS[4,:]
#./(X_visu_NKS[3,:].+X_visu_NKS[4,:])'

scatter([X_visu_NS[1,:],X_visu_NS[1,:]],
    [ScTg(X_visu_NS_sc).data'[:],Be(X_visu_NS_sc).data'[:]],
layout=2)
