# %%
import Flux
using Flux.Tracker, Statistics, DelimitedFiles
using Flux.Tracker: Params, gradient, update!
using Flux: gpu, Dense, BatchNorm, relu, Chain, ADAM, RMSProp, Descent, params, throttle, Dropout, @epochs, testmode!

using Base.Iterators: repeated

using DataFrames, DataFramesMeta, ExcelFiles, MLDataUtils, HDF5, ProgressMeter, Plots, LinearAlgebra, NNlib
pyplot() # pyplot backend

using BSON: @save, @load
# Out:
# WARNING: using ProgressMeter.update! in module Main conflicts with an existing identifier.

# %% [markdown]
# # DATA IMPORT

# %%
path_data = "./data/DataSet_0p20val.hdf5"

X_columns = h5read(path_data, "X_columns")

X_entropy_train = h5read(path_data, "X_entropy_train")
X_entropy_train_sc = h5read(path_data, "X_entropy_train_sc")

X_entropy_valid = h5read(path_data, "X_entropy_valid")
X_entropy_valid_sc = h5read(path_data, "X_entropy_valid_sc")

X_entropy_test = h5read(path_data, "X_entropy_test")
X_entropy_test_sc = h5read(path_data, "X_entropy_test_sc")

X_entropy_tv = [X_entropy_train X_entropy_valid]
X_entropy_sc_tv = [X_entropy_train_sc X_entropy_valid_sc]

X_tv = h5read(path_data, "X_tv")
X_tv_sc = h5read(path_data, "X_tv_sc")
y_tv = h5read(path_data, "y_tv")

X_train = h5read(path_data, "X_train")
X_train_sc = h5read(path_data, "X_train_sc")
y_train = h5read(path_data, "y_train")

X_valid = h5read(path_data, "X_valid")
X_valid_sc = h5read(path_data, "X_valid_sc")
y_valid = h5read(path_data, "y_valid")

X_test = h5read(path_data, "X_test")
X_test_sc = h5read(path_data, "X_test_sc")
y_test = h5read(path_data, "y_test")

X_scaler_mean = h5read(path_data, "X_scaler_mean")
X_scaler_var = h5read(path_data, "X_scaler_var")

X_raman_train = Float32.(h5read("./data/NKAS_DataSet.hdf5","X_raman_train"))
y_raman_train = Float32.((h5read("./data/NKAS_DataSet.hdf5","y_raman_train")))
X_raman_valid = Float32.(h5read("./data/NKAS_DataSet.hdf5","X_raman_test"))
y_raman_valid = Float32.((h5read("./data/NKAS_DataSet.hdf5","y_raman_test")))

println("loaded")
println("\nFeatures in X_ arrays are")
println(X_columns)
println("\nShape of X train and valid is")
println(size(X_train))
println(size(X_valid))

print("Size of Raman datasets")
print(size(X_raman_train))
print(size(y_raman_train))
print(size(X_raman_valid))
print(size(y_raman_valid))
# Out:
# loaded
#
# Features in X_ arrays are
# ["sio2", "al2o3", "na2o", "k2o", "nbot", "ifsm", "ifst", "ap", "b", "T", "Sc", "tg"]
#
# Shape of X train and valid is
# (12, 957)
# (12, 188)
# Size of Raman datasets(4, 31)(850, 31)(4, 14)(850, 14)

# %%
function prepare_datas(X_,y_)
    
    y = reshape(y_[:],1,length(y_))
    
    x = X_[1:4,:]
    ap = reshape(X_[8,:],1,size(X_,2))
    b = reshape(X_[9,:],1,size(X_,2))
    T = reshape(X_[10,:],1,size(X_,2))
    sc = reshape(X_[11,:],1,size(X_,2))
    tg = reshape(X_[12,:],1,size(X_,2))
    return Float32.(x), Float32.(y), Float32.(T), Float32.(ap), Float32.(b), Float32.(sc), Float32.(tg)
end

function gkfolds(X_, y_, idx_label; k = 5)

    dd = kfolds(shuffleobs(unique(X_[idx_label,:])), k = k);
    
    out = []
    
    for j = 1:k
        train_lab, vald_lab = dd[j]
        train_idx = Int64[]
        valid_idx = Int64[]

        for i = 1:size(X_,2)
            if findall(X_[idx_label,i] .== train_lab) != []
                push!(train_idx, i)
            else
                push!(valid_idx, i)
            end
        end
        
        push!(out,((X_[:,train_idx],y_[train_idx]),(X_[:,valid_idx],y_[valid_idx])))
        
    end
    
    return out
end
# Out:
# gkfolds (generic function with 1 method)

# %%
nb_folds = 5
folds = gkfolds(X_train,y_train,8,k=nb_folds);

folds_entropy = gkfolds(X_entropy_tv,X_entropy_tv[11,:],12,k=nb_folds);
folds_entropy_sc = gkfolds(X_entropy_sc_tv,X_entropy_sc_tv[11,:],12,k=nb_folds);

# %% [markdown]
# # Model

# %%
# The model

#
# With two subnetworks for Be and Sc
#

function thousands(size)
    return ones(size).*log.(1000.0)
    end

function tens(size)
    return ones(size).*log.(10.0)
end

function init_both(dims)
    return ones(dims).*[log.(1000.);log.(10.);log.(10.)]
end

init_random(dims...) = randn(Float32, dims...) .* [5.;10.]

nb_neurons_r = 100
nb_neurons_s = 100
nb_neurons_tg = 100
p_drop = 0.3

nb_channels_raman = size(y_raman_train,1)

c1 = Dense(4, nb_neurons_r, relu)
c2 = Dense(nb_neurons_r, nb_neurons_r, relu)
c3 = Dense(nb_neurons_r, nb_neurons_r, relu)
#c4 = Dense(nb_neurons_s, nb_neurons_tg, relu)
#c5 = Dense(nb_neurons_tg, nb_neurons_tg, relu)
#c6 = Dense(nb_neurons, nb_neurons, tanh)

cout_s = Dense(nb_neurons_s, 1,initb=tens) #initW = glorot_uniform
cout_tg = Dense(nb_neurons_tg, 1,initb=thousands) #initW = glorot_uniform

cout_thermo = Dense(nb_neurons_tg, 3,initb=init_both) #initW = glorot_uniform
cout_raman =  Dense(nb_neurons_r,nb_channels_raman)

core = Chain(c1, Dropout(p_drop),
    c2, Dropout(p_drop),
    c3, Dropout(p_drop))

mr = Chain(core, cout_raman) # |> gpu

m1 = Chain(core, cout_thermo) # |> gpu

tg(x) = reshape(exp.(m1(x[1:4,:])[1,:]),1,size(x,2))
ScTg(x) = reshape(exp.(m1(x[1:4,:])[2,:]),1,size(x,2))
fragility(x) = reshape(exp.(m1(x[1:4,:])[3,:]),1,size(x,2))

# Other stuffs
Ae = param([-2.11])
ab_f = param([-3.11,1.0])

Be(x) = (12.0.-Ae).*(tg(x) .* ScTg(x))

dCp(x, T, ap, b) = ap.*(log.(T).-log.(tg(x))) .+ b.*(T.-tg(x))

model(x, T, ap, b) = Ae .+ Be(x) ./ (T.* (ScTg(x) .+ dCp(x, T, ap, b)))

myega(x, T) = Ae .+ (12.0 .- Ae).*(tg(x)./T).*exp.((fragility(x)./(12.0.-Ae).-1.0).*(tg(x)./T.-1.0))

mse(yp, y) = sqrt(sum((yp .- y).^2)./size(y, 2))

# loss functions

loss_n(x, T, ap, b, y_target) = mse(model(x, T, ap, b), y_target)

loss_n_myega(x, T, y_target) = mse(myega(x, T), y_target)

loss_n_tvf(x, T, y_target) = mse(tvf(x,T),y_target)

loss_sc(x,sc) = mse(ScTg(x),sc) # Add this to your loss

loss_tg(x,target) = mse(tg(x),target) # Add this to your loss

loss_f(x) = mse((ab_f[1].*fragility(x).+ab_f[2]),ScTg(x))
# Out:
# loss_f (generic function with 1 method)

# %%
testmode!(m1)
testmode!(mr)

scatter(([X_entropy_tv[12,:],X_entropy_tv[11,:]],
        [tg(X_entropy_tv).data[:],ScTg(X_entropy_tv).data[:]]),layout=2, 
    title=["Tg" "ScTg"])

# %%
scatter(fragility(X_entropy_tv).data[:])

# %%
plot(mr(X_raman_train).data[:,:])

# %% [markdown]
# # Pre-train on Raman

# %%
loss_raman(x,raman_target) = mse(mr(x),raman_target) + L2_norm*sum(norm, params(mr))

L2_norm = 0.001
loss_raman(X_raman_train,y_raman_train)
# Out:
# 60.05487198446932 (tracked)

# %%
# SC training
record_loss_raman_train = Float64[]
record_loss_raman_valid = Float64[]

testmode!(mr,false)

# loop details
epoch_idx = 1; nb_epoch = 2000
optimal_epochs_s = 0; early_stop = 1; patience = 100
min_loss_val = 30000000.0

dataset_raman = [(X_raman_train,y_raman_train)]

p = ProgressMeter.Progress(patience, 1)   # minimum update interval: 1 second
while early_stop < patience

    evalcb = () -> (push!(record_loss_raman_train, loss_raman(X_raman_train, y_raman_train).data),
                    push!(record_loss_raman_valid, loss_raman(X_raman_valid, y_raman_valid).data))
    Flux.train!(loss_raman, params(mr), dataset_raman, ADAM(0.001), cb = throttle(evalcb, 1))

    # Early stopping criterion
    if record_loss_raman_valid[epoch_idx] < min_loss_val
        early_stop = 0
        optimal_epochs = epoch_idx
        min_loss_val = record_loss_raman_valid[epoch_idx]
    else
        early_stop += 1
    end
    
    ProgressMeter.update!(p, early_stop)
    epoch_idx += 1
    
end

print(mean(record_loss_raman_train[end-20:end]))
print("\n")
print(mean(record_loss_raman_valid[end-20:end]))
print("\n")
# Out:
# Progress: 100%|█████████████████████████████████████████| Time: 0:00:25
# 2.950861141382824
# 3.279437115801828

# %%
print(mean(record_loss_raman_train[end-20:end]))
print("\n")
print(mean(record_loss_raman_valid[end-20:end]))
print("\n")
plot(record_loss_raman_train)
plot!(record_loss_raman_valid)
# Out:
# 2.950861141382824
# 3.279437115801828

# %%
testmode!(mr)
plot(mr(X_raman_train).data[:,:],y_raman_train)

# %%
plot(mr(X_raman_train).data[:,:])

# %% [markdown]
# # Pre-train on only entropy + Tg

# %%
# SC training

# loss function
L2_norm = 0.0001 # small L2 there
loss_tg_sc(x,tg_target,sc_target) = 0.001.*loss_tg(x,tg_target) .+ loss_sc(x,sc_target) 
                                        + L2_norm*sum(norm, params(mr))# Add this to your loss

# record loss
record_loss_sc_train = Float64[]
record_loss_sc_valid = Float64[]
record_loss_sc_tv = Float64[]

record_folds_train = Float64[]
record_folds_valid = Float64[]

# unfreeze dropout
testmode!(m1,false)
testmode!(mr,false)

# loop details
epoch_idx = 1; optimal_epochs_s = 0; 
early_stop = 1; patience = 100
min_loss_val = 30000000.0

# loop
p = ProgressMeter.Progress(patience, 1)   # minimum update interval: 1 second
while early_stop < patience

    for j =1:nb_folds

        train,valid = folds_entropy[j]
        x_train_, y_train_, T_train_, ap_train_, b_train_, sc_train_, tg_train_ = prepare_datas(train[1],train[2])
        x_valid_, y_valid_, T_valid_, ap_valid_, b_valid_, sc_valid_, tg_valid_ = prepare_datas(valid[1],valid[2])

        evalcb = () -> (push!(record_folds_train, loss_tg_sc(x_train_, tg_train_, sc_train_).data),
            push!(record_folds_valid, loss_tg_sc(x_valid_, tg_valid_, sc_valid_).data))
        
        Flux.train!(loss_tg_sc, params(m1), [(x_train_, tg_train_, sc_train_)], ADAM(0.001), cb = throttle(evalcb, 1))

    end

    push!(record_loss_sc_train, 1.0./convert(Float64,nb_folds).*sum(record_folds_train))
    push!(record_loss_sc_valid, 1.0./convert(Float64,nb_folds).*sum(record_folds_valid))

    record_folds_train = Float64[]
    record_folds_valid = Float64[]

    ProgressMeter.update!(p, early_stop)

    # Early stopping criterion
    if record_loss_sc_valid[epoch_idx] < min_loss_val
        early_stop = 0
        optimal_epochs = epoch_idx
        min_loss_val = record_loss_sc_valid[epoch_idx]
    else
        early_stop += 1
    end
    epoch_idx += 1
end
# Out:
# Progress:   5%|██                                       |  ETA: 0:28:20
# InterruptException:
#
# Stacktrace:
#  [1] gradient_(::getfield(Flux.Optimise, Symbol("##15#21")){typeof(loss_tg_sc),Tuple{Array{Float32,2},Array{Float32,2},Array{Float32,2}}}, ::Params) at /home/charles/.julia/packages/Tracker/6wcYJ/src/back.jl:7
#  [2] #gradient#24(::Bool, ::Function, ::Function, ::Params) at /home/charles/.julia/packages/Tracker/6wcYJ/src/back.jl:164
#  [3] gradient at /home/charles/.julia/packages/Tracker/6wcYJ/src/back.jl:164 [inlined]
#  [4] macro expansion at /home/charles/.julia/packages/Flux/lz7S9/src/optimise/train.jl:71 [inlined]
#  [5] macro expansion at /home/charles/.julia/packages/Juno/TfNYn/src/progress.jl:133 [inlined]
#  [6] #train!#12(::getfield(Flux, Symbol("#throttled#18")){getfield(Flux, Symbol("##throttled#10#14")){Bool,Bool,getfield(Main, Symbol("##6#7")){Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2}},Int64}}, ::Function, ::Function, ::Params, ::Array{Tuple{Array{Float32,2},Array{Float32,2},Array{Float32,2}},1}, ::ADAM) at /home/charles/.julia/packages/Flux/lz7S9/src/optimise/train.jl:69
#  [7] (::getfield(Flux.Optimise, Symbol("#kw##train!")))(::NamedTuple{(:cb,),Tuple{getfield(Flux, Symbol("#throttled#18")){getfield(Flux, Symbol("##throttled#10#14")){Bool,Bool,getfield(Main, Symbol("##6#7")){Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2},Array{Float32,2}},Int64}}}}, ::typeof(Flux.Optimise.train!), ::Function, ::Params, ::Array{Tuple{Array{Float32,2},Array{Float32,2},Array{Float32,2}},1}, ::ADAM) at ./none:0
#  [8] top-level scope at In[16]:38

# %%
testmode!(m1)
testmode!(mr)

scatter([X_entropy_train[12,:],X_entropy_train[11,:]],
    [tg(X_entropy_train).data[:],ScTg(X_entropy_train).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

scatter!([X_entropy_valid[12,:],X_entropy_valid[11,:]],
    [tg(X_entropy_valid).data[:],ScTg(X_entropy_valid).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

scatter!([X_entropy_test[12,:],X_entropy_test[11,:]],
    [tg(X_entropy_test).data[:],ScTg(X_entropy_test).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

plot!([[700;1500] [4;15]],[[700;1500] [4;15]])

# %%
testmode!(m1)
testmode!(mr)
# Plot
plot([record_loss_sc_train],label="train",xlabel="iterations")
plot!(record_loss_sc_valid,label="valid")

# %%
plot(mr(X_raman_train).data[:,:])

# %% [markdown]
# # Train on loss global : entropy + viscosity

# %%
x_train_, y_train_, T_train_, ap_train_, b_train_, sc_train_, tg_train_ = prepare_datas(X_train,y_train)
x_valid_, y_valid_, T_valid_, ap_valid_, b_valid_, sc_valid_, tg_valid_ = prepare_datas(X_valid,y_valid)

x_entro_train_, y_entro_train_, T_entro_train_, ap_entro_train_, b_entro_train_, sc_entro_train_, tg_entro_train_ = prepare_datas(X_entropy_train,X_entropy_train[11,:])
x_entro_valid_, y_entro_valid_, T_entro_valid_, ap_entro_valid_, b_entro_valid_, sc_entro_valid_, tg_entro_valid_ = prepare_datas(X_entropy_valid,X_entropy_valid[11,:])

print("\nloss Raman: $(loss_raman(X_raman_train, y_raman_train))")
print("\nloss tg: $(loss_tg(x_entro_train_, tg_entro_train_))")
print("\nloss sc: $(loss_sc(x_entro_train_, sc_entro_train_))")
print("\nloss n train: $(loss_n(x_train_, T_train_ ,ap_train_, b_train_, y_train_))")
print("\nloss myega train: $(loss_n_myega(x_train_, T_train_ , y_train))")

L2_norm = 0.1
loss_global(x, T, ap, b, y_target, x2, tg2_target, sc2_target, x_raman, y_raman) = 
    loss_n(x, T, ap, b, y_target) .+ 
    loss_n_myega(x,T,y_target) .+
    #loss_f(x)+
    0.1.*loss_tg(x2,tg2_target) .+ 
    loss_sc(x2,sc2_target) .+
    0.01.*loss_raman(x_raman, y_raman) .+
    L2_norm*sum(norm, params(m1))
# Out:
# loss Raman: 40.614741571801616 (tracked)
# loss tg: 35.0807484250026 (tracked)
# loss sc: 0.6193387590647911 (tracked)
# loss n train: 0.8698906687014094 (tracked)
# loss myega train: 3.6140051115194534 (tracked)
# loss_global (generic function with 1 method)

# %%
record_loss_train = Float64[]
record_loss_valid = Float64[]
    
testmode!(m1,false)
testmode!(mr,false)

epoch_idx = 1; optimal_epochs_s = 0; 
early_stop = 1; patience = 20
min_loss_val = 30000000.0; max_epoch = 4000

p = ProgressMeter.Progress(max_epoch, 1)   # minimum update interval: 1 second

dataset = [(x_train_, T_train_ ,ap_train_, b_train_, y_train_,
                x_entro_train_, tg_entro_train_, sc_entro_train_,X_raman_train, y_raman_train)]

while epoch_idx < max_epoch
    
    evalcb = () -> (push!(record_loss_train, loss_global(x_train_, T_train_ ,ap_train_, b_train_, y_train_,
                x_entro_train_, tg_entro_train_, sc_entro_train_,X_raman_train, y_raman_train).data),
                push!(record_loss_valid, loss_global(x_valid_, T_valid_ ,ap_valid_, b_valid_, y_valid_,
                x_entro_valid_, tg_entro_valid_, sc_entro_valid_,X_raman_valid, y_raman_valid).data))
    Flux.train!(loss_global, params(Ae,m1,mr,ab_f), dataset, ADAM(0.001), cb = throttle(evalcb, 1))

    ProgressMeter.update!(p, epoch_idx)

    # Early stopping criterion
    if record_loss_valid[epoch_idx] < min_loss_val
        early_stop = 0
        optimal_epochs = epoch_idx
        min_loss_val = record_loss_valid[epoch_idx]
        @save "./model/m1.bson" m1
        @save "./model/mr.bson" mr
        @save "./model/Ae.bson" Ae
    else
        early_stop += 1
    end
    epoch_idx += 1
    
end
# Out:
# Progress:  16%|██████▋                                  |  ETA: 0:36:58m
# InterruptException:
#
# Stacktrace:
#  [1] gradient_(::getfield(Flux.Optimise, Symbol("##15#21")){typeof(loss_global),NTuple{10,Array{Float32,2}}}, ::Params) at /home/charles/.julia/packages/Tracker/6wcYJ/src/back.jl:7
#  [2] #gradient#24(::Bool, ::Function, ::Function, ::Params) at /home/charles/.julia/packages/Tracker/6wcYJ/src/back.jl:164
#  [3] gradient at /home/charles/.julia/packages/Tracker/6wcYJ/src/back.jl:164 [inlined]
#  [4] macro expansion at /home/charles/.julia/packages/Flux/lz7S9/src/optimise/train.jl:71 [inlined]
#  [5] macro expansion at /home/charles/.julia/packages/Juno/TfNYn/src/progress.jl:133 [inlined]
#  [6] #train!#12(::getfield(Flux, Symbol("#throttled#18")){getfield(Flux, Symbol("##throttled#10#14")){Bool,Bool,getfield(Main, Symbol("##8#9")),Int64}}, ::Function, ::Function, ::Params, ::Array{NTuple{10,Array{Float32,2}},1}, ::ADAM) at /home/charles/.julia/packages/Flux/lz7S9/src/optimise/train.jl:69
#  [7] (::getfield(Flux.Optimise, Symbol("#kw##train!")))(::NamedTuple{(:cb,),Tuple{getfield(Flux, Symbol("#throttled#18")){getfield(Flux, Symbol("##throttled#10#14")){Bool,Bool,getfield(Main, Symbol("##8#9")),Int64}}}}, ::typeof(Flux.Optimise.train!), ::Function, ::Params, ::Array{NTuple{10,Array{Float32,2}},1}, ::ADAM) at ./none:0
#  [8] top-level scope at In[21]:22

# %%
testmode!(m1)
#println("Optimal number of epochs:", optimal_epochs)
#println("Min loss val:", min_loss_val)
# Plot
plot([record_loss_train],layout=1,label="train", ylabel="MSE Error", xlabel="Iterations", ylim=(0,100))
plot!(record_loss_valid,label="valid")
savefig("./figures/training_error_record.png")
# Out:
# PyPlot.Figure(PyObject <Figure size 600x400 with 1 Axes>)

# %%
testmode!(m1)
scatter([X_entropy_train[12,:],X_entropy_train[11,:]],
    [tg(X_entropy_train).data[:],ScTg(X_entropy_train).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

scatter!([X_entropy_valid[12,:],X_entropy_valid[11,:]],
    [tg(X_entropy_valid).data[:],ScTg(X_entropy_valid).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

scatter!([X_entropy_test[12,:],X_entropy_test[11,:]],
    [tg(X_entropy_test).data[:],ScTg(X_entropy_test).data[:]],
    layout=2, title=["Tg" "Sc(Tg)"])

plot!([[700;1500] [4;15]],[[700;1500] [4;15]])

# %%
plot(mr(X_raman_train).data[:,:],y_raman_train)

# %%
scatter(y_train_[:],
    model(x_train_,T_train_,ap_train_, b_train_).data[:],)
scatter!(y_valid_[:],
    model(x_valid_,T_valid_,ap_valid_, b_valid_).data[:],)
plot!([0.,16.],[0.,16.],ylim=(0,16))

print("\nAdam-Gibbs\n")
print("\nloss n train: $(loss_n(x_train_, T_train_ ,ap_train_, b_train_, y_train_))")
print("\nloss n valid: $(loss_n(x_valid_, T_valid_ ,ap_valid_, b_valid_, y_valid_))")
print("\nMYEGA\n")
print("\nloss n train: $(loss_n_myega(x_train_, T_train_ , y_train_))")
print("\nloss n valid: $(loss_n_myega(x_valid_, T_valid_ , y_valid_))")
# Out:
# Adam-Gibbs
#
# loss n train: 0.6175058974615347 (tracked)
# loss n valid: 0.8036231752838714 (tracked)
# MYEGA
#
# loss n train: 0.6344258538143294 (tracked)
# loss n valid: 0.9274915840792997 (tracked)

# %%
@save "./model/m1.bson" m1
@save "./model/Ae.bson" Ae

# %% [markdown]
# # Visualizing

# %% [markdown]
# # Fragility against Sconf(Tg)

# %%
scatter(fragility(x_train_).data[:],ScTg(x_train_).data[:],xlabel="fragility",ylabel="residual entropy, J mol-1 K-1")

# %%
plot(mr(X_raman_train).data[:,:])

# %%
na2o = collect(0.:0.01:0.25)
k2o = 0.25.-na2o
sio2 = ones(size(na2o,1)).*0.75
al2o3 = zeros(size(na2o,1))
dummy = zeros(size(na2o,1))
T = ones(size(na2o,1)).*1000.0

X_visu_NKS = [sio2 al2o3 na2o k2o dummy dummy dummy dummy dummy T dummy dummy]'

scatter(X_visu_NKS[4,:]./(X_visu_NKS[3,:].+X_visu_NKS[4,:]),ScTg(X_visu_NKS).data'[:],layout=1)
scatter!([0,0.28,0.53,0.82,1.0],[32.91,40.31,37.81,35.59,32.99]./7.0.*2.0,label="richet 1984")
#scatter!(X_visu_NKS[4,:]./(X_visu_NKS[3,:].+X_visu_NKS[4,:]),tg(X_visu_NKS).data'[:],layout=2)

# %%
sio2 = collect(0.6:0.01:1.)
al2o3 = zeros(size(sio2,1))
na2o = 1.0.-sio2
k2o = zeros(size(sio2,1))
dummy = zeros(size(sio2,1))
T = ones(size(sio2,1)).*1000.0
X_visu_NS = [sio2 al2o3 na2o k2o dummy dummy dummy dummy dummy T dummy dummy]'

X_visu_NS_sc = copy(X_visu_NS)

for i = 1:7
    X_visu_NS_sc[i,:] = (X_visu_NS_sc[i,:].- X_scaler_mean[i])./sqrt.(X_scaler_var[i]) 
end
#x_visu_xaxis = X_visu_NKS[4,:]
#./(X_visu_NKS[3,:].+X_visu_NKS[4,:])'

scatter([X_visu_NS[1,:],X_visu_NS[1,:]],
    [ScTg(X_visu_NS).data'[:],Be(X_visu_NS).data'[:]],
layout=2)
