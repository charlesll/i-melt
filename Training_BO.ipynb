# %% [markdown]
# # Library loading

# %%
# %matplotlib inline

import pandas as pd # manipulate dataframes
import matplotlib
import matplotlib.pyplot as plt # plotting
import numpy as np

import time, h5py, imelt, torch

from sklearn.metrics import mean_squared_error

from tqdm import tqdm 

# First we check if CUDA is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

from ax.plot.contour import plot_contour
from ax.plot.slice import plot_slice
from ax.plot.trace import optimization_trace_single_method
from ax.service.managed_loop import optimize
from ax.utils.notebook.plotting import render
from ax.utils.tutorials.cnn_utils import train, evaluate

# Fixing random seeds for reproducibility
np.random.seed = 167 # fix random seed for reproducibility
# Out:
# cuda

# %% [markdown]
# # Training functions

# %%
def net_train(net, dataset, parameterization, dtype, device):
    # handling the network
    net.output_bias_init() # we initialize the output bias
    net.to(dtype=dtype, device=device) # set dtype and send to device

    # Define loss and optimizer
    criterion = torch.nn.MSELoss() # the criterion : MSE
    criterion.to(device)
    
    optimizer = torch.optim.Adam(net.parameters(), 
                                 lr=parameterization.get("lr", 0.001), # 0.001 is used if no lr is specified
                                 weight_decay=parameterization.get("weight_decay", 0.0)) # L2 loss
                
    # training
    net, record_train_loss, record_valid_loss = imelt.training2(net,dataset,criterion,optimizer,
                                                                         save_switch=False,
                                                                         nb_folds=parameterization.get("nb_folds", 20),
                                                                         train_patience=parameterization.get("patience", 10),
                                                                         min_delta=parameterization.get("min_delta", 0.05),
                                                                         verbose=False)

    # to avoid any problem with CUDA memory...
    # del neuralmodel, criterion
    # torch.cuda.empty_cache()
    
    return net, record_train_loss, record_valid_loss

def init_net(parameterization, dataset):

    # get hyperparameters for the network 
    nb_neurons = parameterization.get("nb_neurons", 300)
    nb_layers = parameterization.get("nb_layers", 3)
    p_drop = parameterization.get("p_drop", 0.05)
    
    # model declaration
    model = imelt.model(4,nb_neurons,nb_layers,dataset.nb_channels_raman, p_drop) # declaring model
                                  
    return model # return untrained model

def train_evaluate(parameterization):

    # Get neural net
    untrained_net = init_net(parameterization, dataset) 
    
    # train
    trained_net, record_train_loss, record_valid_loss = net_train(untrained_net, dataset, 
                            parameterization, dtype=dtype, device=device)
    
    output = {"loss_train": (record_train_loss[-1], 0.0), "loss_valid": (record_valid_loss[-1], 0.0)}
    
    # return the accuracy of the model as it was trained in this run
    return output

# %% [markdown]
# # Launching the BO experiment

# %%
#torch.cuda.set_device(0) #this is sometimes necessary for me
dtype = torch.float
#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# custom data loader, automatically sent to device
dataset = imelt.data_loader("./data/NKAS_viscosity_reference.hdf5",
                         "./data/NKAS_Raman.hdf5",
                         "./data/NKAS_density.hdf5",
                         "./data/NKAS_optical.hdf5",
                         device)

best_parameters, values, experiment, model = optimize(
    parameters=[
        {"name": "nb_neurons", "type": "range", "bounds": [100, 500]},
        {"name": "nb_layers", "type": "range", "bounds": [2, 8]},
        {"name": "lr", "type": "range", "bounds": [1e-5, 0.001]}, # 0.008
        {"name": "nb_folds", "type": "range", "bounds": [2, 30]}, # 0.008
        #{"name": "min_delta", "type": "range", "bounds": [0.01, 1.0]},
        #{"name": "patience", "type": "range", "bounds": [10, 500]},
        #{"name": "weight_decay", "type": "range", "bounds": [1.0e-5, 1.0e-2]},        
    ],
    total_trials = 100,
    evaluation_function=train_evaluate,
    objective_name='loss_valid',
)

print(best_parameters)
means, covariances = values
print(means)
print(covariances)
#view raw
# Out:
# [INFO 06-22 18:06:22] ax.service.utils.instantiation: Inferred value type of ParameterType.INT for parameter nb_neurons. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-22 18:06:22] ax.service.utils.instantiation: Inferred value type of ParameterType.INT for parameter nb_layers. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-22 18:06:22] ax.service.utils.instantiation: Inferred value type of ParameterType.FLOAT for parameter lr. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-22 18:06:22] ax.service.utils.instantiation: Inferred value type of ParameterType.INT for parameter nb_folds. If that is not the expected value type, you can explicity specify 'value_type' ('int', 'float', 'bool' or 'str') in parameter dict.
# [INFO 06-22 18:06:22] ax.modelbridge.dispatch_utils: Using Bayesian Optimization generation strategy: GenerationStrategy(name='Sobol+GPEI', steps=[Sobol for 5 trials, GPEI for subsequent trials]). Iterations after 5 will take longer to generate due to  model-fitting.
# [INFO 06-22 18:06:22] ax.service.managed_loop: Started full optimization with 100 steps.
# [INFO 06-22 18:06:22] ax.service.managed_loop: Running optimization trial 1...
# [INFO 06-22 18:07:26] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:07:26] ax.service.managed_loop: Running optimization trial 2...
# [INFO 06-22 18:08:22] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:08:22] ax.service.managed_loop: Running optimization trial 3...
# [INFO 06-22 18:10:20] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:10:20] ax.service.managed_loop: Running optimization trial 4...
# [INFO 06-22 18:11:10] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:11:10] ax.service.managed_loop: Running optimization trial 5...
# [INFO 06-22 18:11:36] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:11:36] ax.service.managed_loop: Running optimization trial 6...
# [INFO 06-22 18:12:16] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:12:16] ax.service.managed_loop: Running optimization trial 7...
# [INFO 06-22 18:12:36] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:12:36] ax.service.managed_loop: Running optimization trial 8...
# [INFO 06-22 18:12:46] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:12:46] ax.service.managed_loop: Running optimization trial 9...
# [INFO 06-22 18:12:57] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:12:57] ax.service.managed_loop: Running optimization trial 10...
# [INFO 06-22 18:13:10] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:13:10] ax.service.managed_loop: Running optimization trial 11...
# [INFO 06-22 18:13:23] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:13:23] ax.service.managed_loop: Running optimization trial 12...
# [INFO 06-22 18:13:30] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:13:30] ax.service.managed_loop: Running optimization trial 13...
# [INFO 06-22 18:13:44] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:13:44] ax.service.managed_loop: Running optimization trial 14...
# [INFO 06-22 18:13:55] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:13:55] ax.service.managed_loop: Running optimization trial 15...
# [INFO 06-22 18:14:12] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:14:12] ax.service.managed_loop: Running optimization trial 16...
# [INFO 06-22 18:14:24] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:14:24] ax.service.managed_loop: Running optimization trial 17...
# [INFO 06-22 18:14:32] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:14:32] ax.service.managed_loop: Running optimization trial 18...
# [INFO 06-22 18:14:41] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:14:41] ax.service.managed_loop: Running optimization trial 19...
# [INFO 06-22 18:14:52] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:14:52] ax.service.managed_loop: Running optimization trial 20...
# [INFO 06-22 18:15:00] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:15:00] ax.service.managed_loop: Running optimization trial 21...
# [INFO 06-22 18:15:09] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:15:09] ax.service.managed_loop: Running optimization trial 22...
# [INFO 06-22 18:15:20] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:15:20] ax.service.managed_loop: Running optimization trial 23...
# [INFO 06-22 18:15:31] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:15:31] ax.service.managed_loop: Running optimization trial 24...
# [INFO 06-22 18:16:16] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:16:16] ax.service.managed_loop: Running optimization trial 25...
# [INFO 06-22 18:16:27] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:16:27] ax.service.managed_loop: Running optimization trial 26...
# [INFO 06-22 18:16:37] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:16:37] ax.service.managed_loop: Running optimization trial 27...
# [INFO 06-22 18:16:43] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:16:43] ax.service.managed_loop: Running optimization trial 28...
# [INFO 06-22 18:17:37] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:17:37] ax.service.managed_loop: Running optimization trial 29...
# [INFO 06-22 18:20:06] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:20:06] ax.service.managed_loop: Running optimization trial 30...
# [INFO 06-22 18:21:55] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:21:55] ax.service.managed_loop: Running optimization trial 31...
# [INFO 06-22 18:23:48] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:23:48] ax.service.managed_loop: Running optimization trial 32...
# [INFO 06-22 18:24:33] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:24:33] ax.service.managed_loop: Running optimization trial 33...
# [INFO 06-22 18:24:47] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:24:47] ax.service.managed_loop: Running optimization trial 34...
# [INFO 06-22 18:25:25] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:25:25] ax.service.managed_loop: Running optimization trial 35...
# [INFO 06-22 18:25:57] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:25:57] ax.service.managed_loop: Running optimization trial 36...
# [INFO 06-22 18:26:51] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:26:51] ax.service.managed_loop: Running optimization trial 37...
# [INFO 06-22 18:28:51] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:28:51] ax.service.managed_loop: Running optimization trial 38...
# [INFO 06-22 18:29:47] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:29:47] ax.service.managed_loop: Running optimization trial 39...
# [INFO 06-22 18:31:39] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:31:39] ax.service.managed_loop: Running optimization trial 40...
# [INFO 06-22 18:33:20] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:33:20] ax.service.managed_loop: Running optimization trial 41...
# [INFO 06-22 18:34:19] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:34:19] ax.service.managed_loop: Running optimization trial 42...
# [INFO 06-22 18:34:53] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:34:53] ax.service.managed_loop: Running optimization trial 43...
# [INFO 06-22 18:36:48] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:36:48] ax.service.managed_loop: Running optimization trial 44...
# [INFO 06-22 18:38:59] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:38:59] ax.service.managed_loop: Running optimization trial 45...
# [INFO 06-22 18:40:04] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:40:04] ax.service.managed_loop: Running optimization trial 46...
# [INFO 06-22 18:41:03] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:41:03] ax.service.managed_loop: Running optimization trial 47...
# [INFO 06-22 18:41:25] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:41:25] ax.service.managed_loop: Running optimization trial 48...
# [INFO 06-22 18:44:36] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:44:36] ax.service.managed_loop: Running optimization trial 49...
# [INFO 06-22 18:45:26] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:45:26] ax.service.managed_loop: Running optimization trial 50...
# [INFO 06-22 18:46:20] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:46:20] ax.service.managed_loop: Running optimization trial 51...
# [INFO 06-22 18:47:58] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:47:58] ax.service.managed_loop: Running optimization trial 52...
# [INFO 06-22 18:48:41] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:48:41] ax.service.managed_loop: Running optimization trial 53...
# [INFO 06-22 18:49:43] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:49:43] ax.service.managed_loop: Running optimization trial 54...
# [INFO 06-22 18:50:12] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:50:12] ax.service.managed_loop: Running optimization trial 55...
# [INFO 06-22 18:52:10] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:52:10] ax.service.managed_loop: Running optimization trial 56...
# [INFO 06-22 18:52:45] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:52:45] ax.service.managed_loop: Running optimization trial 57...
# [INFO 06-22 18:53:16] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:53:16] ax.service.managed_loop: Running optimization trial 58...
# [INFO 06-22 18:53:55] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:53:55] ax.service.managed_loop: Running optimization trial 59...
# [INFO 06-22 18:54:22] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:54:22] ax.service.managed_loop: Running optimization trial 60...
# [INFO 06-22 18:54:44] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:54:44] ax.service.managed_loop: Running optimization trial 61...
# [INFO 06-22 18:56:40] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:56:40] ax.service.managed_loop: Running optimization trial 62...
# [INFO 06-22 18:57:24] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:57:24] ax.service.managed_loop: Running optimization trial 63...
# [INFO 06-22 18:59:26] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 18:59:26] ax.service.managed_loop: Running optimization trial 64...
# [INFO 06-22 19:00:53] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 19:00:53] ax.service.managed_loop: Running optimization trial 65...
# [INFO 06-22 19:02:25] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 19:02:25] ax.service.managed_loop: Running optimization trial 66...
# [INFO 06-22 19:03:44] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 19:03:44] ax.service.managed_loop: Running optimization trial 67...
# [INFO 06-22 19:04:15] ax.core.experiment: Attached data has some metrics ({'loss_train'}) that are not among the metrics on this experiment. Note that attaching data will not automatically add those metrics to the experiment. For these metrics to be automatically fetched by `experiment.fetch_data`, add them via `experiment.add_tracking_metric` or update the experiment's optimization config.
# [INFO 06-22 19:04:15] ax.service.managed_loop: Running optimization trial 68...
# [ERROR 06-22 19:04:15] ax.service.managed_loop: Encountered exception during optimization:
# Traceback (most recent call last):
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/service/managed_loop.py", line 178, in full_run
#     self.run_trial()
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/utils/common/executils.py", line 98, in actual_wrapper
#     return func(*args, **kwargs)
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/service/managed_loop.py", line 153, in run_trial
#     generator_run=self.generation_strategy.gen(
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/generation_strategy.py", line 406, in gen
#     return self._gen_multiple(
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/generation_strategy.py", line 476, in _gen_multiple
#     self._set_or_update_model(data=data)
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/generation_strategy.py", line 537, in _set_or_update_model
#     self._set_or_update_current_model(data=data)
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/generation_strategy.py", line 572, in _set_or_update_current_model
#     self._set_current_model(data=data)
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/generation_strategy.py", line 639, in _set_current_model
#     self._set_current_model_from_models_enum(data=data, **model_kwargs)
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/generation_strategy.py", line 681, in _set_current_model_from_models_enum
#     self._model = self._curr.model(experiment=self.experiment, data=data, **kwargs)
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/registry.py", line 261, in __call__
#     model_bridge = bridge_class(
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/torch.py", line 66, in __init__
#     super().__init__(
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/base.py", line 162, in __init__
#     self._fit(
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/torch.py", line 98, in _fit
#     super()._fit(
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/array.py", line 79, in _fit
#     self._model_fit(
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/modelbridge/torch.py", line 137, in _model_fit
#     self.model.fit(
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/models/torch/botorch.py", line 292, in fit
#     self.model = self.model_constructor(  # pyre-ignore [28]
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/models/torch/botorch_defaults.py", line 120, in get_and_fit_model
#     model = _get_model(
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/ax/models/torch/botorch_defaults.py", line 528, in _get_model
#     gp = SingleTaskGP(train_X=X, train_Y=Y, input_transform=warp_tf, **kwargs)
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/botorch/models/gp_regression.py", line 102, in __init__
#     validate_input_scaling(train_X=transformed_X, train_Y=train_Y)
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/botorch/models/utils.py", line 222, in validate_input_scaling
#     check_no_nans(train_Y)
#   File "/home/charles/anaconda3/envs/ml/lib/python3.8/site-packages/botorch/models/utils.py", line 131, in check_no_nans
#     raise InputDataError("Input data contains NaN values.")
# botorch.exceptions.errors.InputDataError: Input data contains NaN values.
# {'nb_neurons': 461, 'nb_layers': 2, 'lr': 0.0006179899391140026, 'nb_folds': 2}
# {'loss_valid': 39.316041493612765, 'loss_train': 21.28754931464348}
# {'loss_valid': {'loss_valid': 1.720429152784467e-06, 'loss_train': 0.0}, 'loss_train': {'loss_valid': 0.0, 'loss_train': 7.18096285017969e-07}}

# %%
render(plot_contour(model=model, param_x='nb_layers', param_y='nb_neurons', metric_name='loss_valid'))
# Out:
# <div>                            <div id="93bb5a0e-8531-4be3-a98f-c030a12ee4d5" class="plotly-graph-div" style="height:450px; width:950px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93bb5a0e-8531-4be3-a98f-c030a12ee4d5")) {                    Plotly.newPlot(                        "93bb5a0e-8531-4be3-a98f-c030a12ee4d5",                        [{"autocolorscale": false, "autocontour": true, "colorbar": {"tickfont": {"size": 8}, "ticksuffix": "", "x": 0.45, "y": 0.5}, "colorscale": [[0.0, "rgb(247,252,253)"], [0.125, "rgb(229,245,249)"], [0.25, "rgb(204,236,230)"], [0.375, "rgb(153,216,201)"], [0.5, "rgb(102,194,164)"], [0.625, "rgb(